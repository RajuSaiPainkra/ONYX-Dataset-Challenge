# %% [markdown]
# <a href="https://www.kaggle.com/code/rajusaipainkra/merchandise-sales-dataset-onyx-january-2025?scriptVersionId=216597178" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # The ONYX January 2025 Challenge
# ## "Merchandise Sales Dataset Challenge"

# %% [markdown]
# #### Merchandise Sales Dataset Challenge : Understanding

# %% [markdown]
# we aim to explore the **Merchandise Sales Dataset** for *Lee Chatmen*, a prominent **influencer** from the United States with over 7 million TikTok followers.
#
# Lee's popularity grew from his entertaining videos featuring popular songs played on miniature guitars. In 2023,
#
# he expanded his brand by launching his own line of merchandise, and now we aim to analyze the sales data of these products.

# %% [markdown]
# ### <u>Key Objective:</u>

# %% [markdown]
# The goal of this phase is to understand the business context, outline the key questions driving the analysis, and identify potential opportunities for data exploration that can offer valuable insights for Lee's business.

# %% [markdown]
# ### <u> Key Business Questions to Explore: </u>

# %% [markdown]
#
# **Overall Sales Trends:** How have sales evolved over time? Are there seasonal patterns or spikes linked to specific events or promotions? <br>
# *What are the overall sales trends?*
#
# **Product Performance:** Which product categories are performing the best? What are the most and least popular products in terms of sales volume and revenue?<br>
# *Which product categories perform the best?*
#
#
# **Location Impact:** How do different geographic locations (countries, regions, cities) affect sales performance?<br>
# *How does location affect sales performance?*
#
#
# **International Shipping:** What role does international shipping play in customer behavior and sales trends? How do shipping costs and delivery times influence purchasing decisions?<br>
# *What impact does international shipping have on sales?*
#
# **Customer Demographics:**</li> What are the demographic characteristics of the buyers (age, gender, etc.)? How do they correlate with sales patterns?<br>
# *What is the demographic profile of buyers?*
#
#
# **Ratings & Reviews Correlation:** How do product ratings and customer reviews impact product sales and overall performance?<br>
# *How do ratings and reviews correlate with sales?*
#
# **Shipping Charges:** What are the trends in shipping charges, and how do they affect purchasing behavior and order value?<br>
# What impact does international shipping have on sales?
# *What are the trends in shipping charges?*
#
#
# **Discounts and Promotions:** How do special offers, discounts, or promotional pricing influence consumer purchasing decisions?<br>
# *How do discounts or promotional pricing influence purchasing behavior?*
#
# **Repeat Purchases:** Are there any patterns in repeat purchases, and what factors drive customer loyalty?<br>
# *Are there any patterns in repeat purchases?*
#
# **What are the most and least popular products?**

# %% [markdown]
# <hr>

# %% [markdown]
# #### Merchandise Sales Dataset Challenge : Data Understanding

# %%
# import library
import pandas as pd

# %%
# check the excel file and its sheets 
excel_file = pd.ExcelFile("/kaggle/input/merchandise-sales-onyx-dataset-january-2025/Onyx Data -DataDNA Dataset Challenge - Merchandise Sales Dataset - January 2025.xlsx")

# checking, number of sheets
print(f"Number of Sheet in the Excel : {len(excel_file.sheet_names)}")

# sheets in Excel 
print(f"Sheets in the Excel : {excel_file.sheet_names}")
# Out:
# Number of Sheet in the Excel : 2
# Sheets in the Excel : ['Data', 'Dictionary']

# %%
# import Dictionary Datasets
dictionary_data = pd.read_excel("/kaggle/input/merchandise-sales-onyx-dataset-january-2025/Onyx Data -DataDNA Dataset Challenge - Merchandise Sales Dataset - January 2025.xlsx", sheet_name = "Dictionary")


# Number of Columns 
print("Number of columns in Dictionary Data Sheet : ", len(dictionary_data.columns))
# Columns
print("Columns in Dictionary Data Sheet : ", dictionary_data.columns)
# Out:
# Number of columns in Dictionary Data Sheet :  2
# Columns in Dictionary Data Sheet :  Index(['Order ID: ', 'Serves as an identifier for each order made.'], dtype='object')

# %%
print(dictionary_data)
# Out:
#                   Order ID:   \
# 0               Order Date:
# 1               Product ID:
# 2         Product Category:
# 3             Buyer Gender:
# 4                Buyer Age:
# 5           Order Location:
# 6                   Latitude
# 7                  Longitude
# 8   International Shipping:
# 9              Sales Price:
# 10        Shipping Charges:
# 11          Sales per Unit:
# 12                Quantity:
# 13             Total Sales:
# 14                  Rating:
# 15                  Review:
#
#          Serves as an identifier for each order made.
# 0                   The date when the order was made.
# 1   Serves as an identifier for the product that w...
# 2   Category of Product sold (Clothing, Ornaments,...
# 3   Genders of people that have ordered from the w...
# 4                                 Ages of the buyers.
# 5             The city where the order was made from.
# 6   Latitude specifies the geographic coordinate t...
# ...

# %%
# Checking the Dictionary Datasets Columns : Order Id , Serves as an identifier for each or der made"

# Get the number of rows and columns in the DataFrame
rows, columns = dictionary_data.shape

# Display the number of rows and columns
print("Number of Rows :", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows : 16
# Number of Columns: 2

# %% [markdown]
# **Output About - Dictionary Datasheet :** MetaData about Main Data Sheet(named : Data)

# %% [markdown]
# <hr>

# %% [markdown]
# #  Initial Data Exploration

# %%
# import 'data' sheet from the ExcelFile

data_file = pd.read_excel(excel_file, sheet_name = "Data")

# check the Rows and Columns
rows, columns = data_file.shape

print("\nRows in Data : ", rows)
print("\nColumns in Data : ", columns)


# Checking Columns
print("\nColumns in Data : \n", data_file.columns.tolist())
# Out:
# Rows in Data :  7394
#
# Columns in Data :  17
#
# Columns in Data :
#  ['Order ID', 'Order Date', 'Product ID', 'Product Category', 'Buyer Gender', 'Buyer Age', 'Order Location', 'Latitude', 'Longitude', 'International Shipping', 'Sales Price', 'Shipping Charges', 'Sales per Unit', 'Quantity', 'Total Sales', 'Rating', 'Review']

# %%
print(rows)
# Out:
# 7394

# %%
print(columns)
# Out:
# 17

# %% [markdown]
# **Until Now What we get :** we have Tabular Dataset
#
# check the *data.head()* <br>
# then, Time to Categorize the Tabluar Data into : (Types of data in datasets)
# <ul>
#     <li>Numerical Dataset</li>
#     <li>Categorical Datasets</li>
#     <li>Ordinal Datasets</li>
# </ul>

# %%
# Data's upper 10 rows
print(data_file.head(10))
# Out:
#    Order ID Order Date Product ID Product Category Buyer Gender  Buyer Age  \
# 0    189440 2024-07-21     BF1543         Clothing         Male         30
# 1    187385 2024-07-20     BF1543         Clothing         Male         32
# 2    181844 2024-07-21     BF1544            Other       Female         26
# 3    197934 2024-08-19     BF1544            Other         Male         28
# 4    122470 2024-01-06     BF1545            Other       Female         19
# 5    199680 2024-06-01     BF1546         Clothing         Male         29
# 6    130929 2024-03-06     BF1547        Ornaments         Male         32
# 7    164427 2024-04-16     BF1547        Ornaments         Male         26
# 8    149510 2024-05-22     BF1545            Other       Female         26
# 9    176280 2024-02-27     BF1548         Clothing         Male         20
#
#   Order Location   Latitude   Longitude International Shipping  Sales Price  \
# ...

# %% [markdown]
# ##  Inspect Data Types

# %%
data_file.dtypes # Checking Data Types
# Out:
# Order ID                           int64
# Order Date                datetime64[ns]
# Product ID                        object
# Product Category                  object
# Buyer Gender                      object
# Buyer Age                          int64
# Order Location                    object
# Latitude                         float64
# Longitude                        float64
# International Shipping            object
# Sales Price                        int64
# Shipping Charges                   int64
# Sales per Unit                     int64
# Quantity                           int64
# Total Sales                        int64
# Rating                             int64
# Review                            object
# dtype: object

# %%
data_file["Product ID"].unique().tolist()
# Out:
# ['BF1543',
#  'BF1544',
#  'BF1545',
#  'BF1546',
#  'BF1547',
#  'BF1548',
#  'BF1549',
#  'BF1550',
#  'BF1551',
#  'BF1552',
#  'BF1553',
#  'BF1554',
#  'BF1555']

# %%
len(data_file["Order Location"].unique())
# Out:
# 25

# %%
data_file["Buyer Age"].describe()
# Out:
# count    7394.000000
# mean       26.455504
# std         5.208202
# min        18.000000
# 25%        22.000000
# 50%        26.000000
# 75%        31.000000
# max        35.000000
# Name: Buyer Age, dtype: float64

# %%
print("count the element in Product Category : \n", len(data_file["Product Category"].unique()))
print("\nElement in Product Category : \n", data_file["Product Category"].unique())
# Out:
# count the element in Product Category :
#  3
#
# Element in Product Category :
#  ['Clothing' 'Other' 'Ornaments']

# %%
# Classification the Column in Numerical, Ordinal, Categorical Datasets

# %%
def categorize_columns(data_file):
    numerical_colm = []
    categorical_colm = []
    ordinal_colm = []

    for column in data_file.columns:
        if data_file[column].dtype in ['int64', 'float64']: # for Numerical Columns
            numerical_colm.append(column)
        elif data_file[column].dtype == "object": # for Categorical Columns
            categorical_colm.append(column)
        else:
            ordinal_colm.append(column)
    return numerical_colm, categorical_colm, ordinal_colm

# categorize the column
numerical_colm, categorical_colm, ordinal_colm = categorize_columns(data_file)

# print the result
print("Numerical Columns : ", numerical_colm)
print("\nCategorical Columns : ", categorical_colm)
print("\nOrdinal Columns : ", ordinal_colm )
# Out:
# Numerical Columns :  ['Order ID', 'Buyer Age', 'Latitude', 'Longitude', 'Sales Price', 'Shipping Charges', 'Sales per Unit', 'Quantity', 'Total Sales', 'Rating']
#
# Categorical Columns :  ['Product ID', 'Product Category', 'Buyer Gender', 'Order Location', 'International Shipping', 'Review']
#
# Ordinal Columns :  ['Order Date']

# %%
# checking Ordinal Data
print(data_file['Order Date'])
# Out:
# 0      2024-07-21
# 1      2024-07-20
# 2      2024-07-21
# 3      2024-08-19
# 4      2024-01-06
#           ...
# 7389   2023-12-10
# 7390   2024-01-24
# 7391   2023-12-19
# 7392   2023-12-07
# 7393   2024-10-23
# Name: Order Date, Length: 7394, dtype: datetime64[ns]

# %% [markdown]
# ## Check for Errors

# %%
data_file[numerical_colm].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7394 entries, 0 to 7393
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          7394 non-null   int64
#  1   Buyer Age         7394 non-null   int64
#  2   Latitude          7394 non-null   float64
#  3   Longitude         7394 non-null   float64
#  4   Sales Price       7394 non-null   int64
#  5   Shipping Charges  7394 non-null   int64
#  6   Sales per Unit    7394 non-null   int64
#  7   Quantity          7394 non-null   int64
#  8   Total Sales       7394 non-null   int64
#  9   Rating            7394 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 577.8 KB

# %%
data_file[categorical_colm].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7394 entries, 0 to 7393
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Product ID              7394 non-null   object
#  1   Product Category        7394 non-null   object
#  2   Buyer Gender            7394 non-null   object
#  3   Order Location          7394 non-null   object
#  4   International Shipping  7394 non-null   object
#  5   Review                  7394 non-null   object
# dtypes: object(6)
# memory usage: 346.7+ KB

# %%
data_file[ordinal_colm].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7394 entries, 0 to 7393
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  7394 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 57.9 KB

# %% [markdown]
# **Here is No - Missing Values**

# %% [markdown]
# ## Check for Missing Values : Again

# %%
# Check for missing values in the dataset
missing_value_numerical_colm = data_file[numerical_colm].isnull().sum()
missing_value_categorical_colm = data_file[categorical_colm].isnull().sum()
missing_value_ordinal_colm = data_file[ordinal_colm].isnull().sum()


# # Display columns with missing values
print("Missing Value in Numerial Columns :\n", missing_value_numerical_colm, "\n")
print("Missing value in Categorical Columns :\n",missing_value_categorical_colm, "\n")
print("Missing value in Ordinal Columns : \n", missing_value_ordinal_colm)
# Out:
# Missing Value in Numerial Columns :
#  Order ID            0
# Buyer Age           0
# Latitude            0
# Longitude           0
# Sales Price         0
# Shipping Charges    0
# Sales per Unit      0
# Quantity            0
# Total Sales         0
# Rating              0
# dtype: int64
#
# Missing value in Categorical Columns :
#  Product ID                0
# Product Category          0
# Buyer Gender              0
# Order Location            0
# International Shipping    0
# Review                    0
# dtype: int64
#
# Missing value in Ordinal Columns :
#  Order Date    0
# dtype: int64

# %% [markdown]
# # Descriptive Statistics

# %%
# Summary statistics for numerical columns
print(data_file.describe())
# Out:
#             Order ID                     Order Date    Buyer Age     Latitude  \
# count    7394.000000                           7394  7394.000000  7394.000000
# mean   159735.134028  2024-05-02 16:09:05.307005696    26.455504    37.988751
# min    120005.000000            2023-11-05 00:00:00    18.000000   -33.865143
# 25%    139895.750000            2024-02-02 00:00:00    22.000000    35.117500
# 50%    159577.500000            2024-04-30 00:00:00    26.000000    39.833851
# 75%    179869.750000            2024-07-31 00:00:00    31.000000    45.508888
# max    199994.000000            2024-11-04 00:00:00    35.000000    55.860916
# std     23040.247194                            NaN     5.208202    14.211051
#
#          Longitude  Sales Price  Shipping Charges  Sales per Unit  \
# count  7394.000000  7394.000000       7394.000000     7394.000000
# mean    -63.504667    55.165404         14.633487       69.798891
# min    -122.676210     9.000000          0.000000        9.000000
# ...

# %% [markdown]
# data.describe() generates statistics like mean, standard deviation, minimum, maximum, and quartiles for numerical columns.

# %%
# Include categorical columns for a more comprehensive summary
print(data_file.describe(include='object'))
# Out:
#        Product ID Product Category Buyer Gender Order Location  \
# count        7394             7394         7394           7394
# unique         13                3            2             25
# top        BF1548         Clothing         Male     New Jersey
# freq         1497             3704         5188            434
#
#        International Shipping                                           Review
# count                    7394                                             7394
# unique                      2                                               29
# top                        No  Lack of delivery delays is greatly appreciated.
# freq                     5139                                              466

# %% [markdown]
# Adding include='object' provides a summary for Integer Numerical columns, including the count, unique values, most frequent value, and its frequency.

# %%
print(data_file.describe(include=['int64']))
# Out:
#             Order ID    Buyer Age  Sales Price  Shipping Charges  \
# count    7394.000000  7394.000000  7394.000000       7394.000000
# mean   159735.134028    26.455504    55.165404         14.633487
# std     23040.247194     5.208202    39.575614         24.815719
# min    120005.000000    18.000000     9.000000          0.000000
# 25%    139895.750000    22.000000    15.000000          0.000000
# 50%    159577.500000    26.000000    65.000000          0.000000
# 75%    179869.750000    31.000000    97.000000         40.000000
# max    199994.000000    35.000000   130.000000        100.000000
#
#        Sales per Unit     Quantity  Total Sales       Rating
# count     7394.000000  7394.000000  7394.000000  7394.000000
# mean        69.798891     1.668109   115.832026     3.499053
# std         46.702326     1.081398   118.067960     1.389731
# min          9.000000     1.000000     9.000000     1.000000
# 25%         20.000000     1.000000    40.000000     3.000000
# ...

# %% [markdown]
# Adding include='int64' provides a summary for categorical columns, including the count, unique values, most frequent value, and its frequency.

# %%
print(data_file.describe(include=['float64']))
# Out:
#           Latitude    Longitude
# count  7394.000000  7394.000000
# mean     37.988751   -63.504667
# std      14.211051    61.087486
# min     -33.865143  -122.676210
# 25%      35.117500   -98.491142
# 50%      39.833851   -80.191788
# 75%      45.508888    -6.266155
# max      55.860916   151.209900

# %% [markdown]
# Adding include='float64' provides a summary for float Numerical  columns, including the count, unique values, most frequent value, and its frequency.

# %% [markdown]
# ## Data Distribution

# %% [markdown]
# ### For Continuous Variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing distribution of all numerical columns
data_file.hist(figsize=(10, 8), bins=20, edgecolor='k')
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing distribution of all numerical columns
num_columns = data_file.select_dtypes(include=['int64', 'float64']).columns  # Select numerical columns
num_features = len(num_columns)  # Count of numerical features

# Create subplots with an appropriate grid size
rows = (num_features // 3) + (1 if num_features % 3 != 0 else 0)  # Calculate rows for a grid of 3 columns
fig, axes = plt.subplots(rows, 3, figsize=(15, 5 * rows))  # Adjust figure size for better spacing
axes = axes.flatten()  # Flatten to iterate over each subplot easily

# Plot each numerical feature
for i, col in enumerate(num_columns):
    sns.histplot(data_file[col], bins=20, kde=False, ax=axes[i], color='skyblue', edgecolor='k')
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

# Remove empty subplots (if any)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])  # Delete unused axes

# Add spacing and adjust layout
plt.tight_layout()
plt.suptitle('Histograms of Numerical Features', y=1.02, fontsize=16)  # Add a main title
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
